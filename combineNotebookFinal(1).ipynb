# %%
import pandas as pd
import numpy as np

# %%
combine_data_2013 = pd.read_csv('../data/combine_data_2013.csv')
combine_data_2014 = pd.read_csv('../data/combine_data_2014.csv')
combine_data_2015 = pd.read_csv('../data/combine_data_2015.csv')
combine_data_2016 = pd.read_csv('../data/combine_data_2016.csv')
combine_data_2017 = pd.read_csv('../data/combine_data_2017.csv')

# %%
player_data_2013 = pd.read_csv('../data/player_data_2013.csv')
player_data_2014 = pd.read_csv('../data/player_data_2014.csv')
player_data_2015 = pd.read_csv('../data/player_data_2015.csv')
player_data_2016 = pd.read_csv('../data/player_data_2016.csv')
player_data_2017 = pd.read_csv('../data/player_data_2017.csv')

# %% [markdown]
# Note these dataframes below are going to be used to compare to see if a player has played a game. Due to the lack of complete data that has been sourced to tell whether a player plays a game or not this data will be able to source the last bit we need in order to get a more complete dataset.
#
# First 2013, 2014, and 2015 will be combined due to how they are formated. Then 2016 and 2017 will be combined and finally we will combine the two accumulated datasets.

# %%
copied_player_data_2013 = pd.read_csv('../data/NFL 2013_final.csv')
copied_player_data_2014 = pd.read_csv('../data/NFL 2014_final.csv')
copied_player_data_2015 = pd.read_csv('../data/NFL 2015_final.csv')
copied_player_data_2016 = pd.read_csv('../data/NFL 2016_final.csv')
copied_player_data_2017 = pd.read_csv('../data/NFL 2017_final.csv')
copied_player_data_2014['GP']
# Out:
# 0      16.0
# 1       NaN
# 2      12.0
# 3      15.0
# 4       8.0
#        ...
# 302     NaN
# 303     NaN
# 304     NaN
# 305     NaN
# 306     NaN
# Name: GP, Length: 307, dtype: float64

# %%
copied_df1 = pd.DataFrame(columns=['Name', 'GP'])
combine_df = [copied_player_data_2013,copied_player_data_2014,copied_player_data_2015]
for df in combine_df:
    copied_df1 = pd.concat([copied_df1, df[['Name', 'GP']]], ignore_index=True)
    
copied_df1
# Out:
#                   Name    GP
# 0        Braxston Cave   NaN
# 1       Brian Schwenke   9.0
# 2           Joe Madsen   NaN
# 3    Matt Stankiewitch   NaN
# 4        P.J. Lonergan   NaN
# ..                 ...   ...
# 900        Andrew East   NaN
# 901   Easton Wahlstrom   NaN
# 902      Jesse Schmitt   NaN
# 903        Joe Cardona  16.0
# 904        Matt Dooley   NaN
#
# [905 rows x 2 columns]

# %%
copied_df2 = pd.DataFrame(columns=['Player', 'GP'])
combine_df = [copied_player_data_2016,copied_player_data_2017]
for df in combine_df:
    copied_df2 = pd.concat([copied_df2, df[['Player', 'GP']]], ignore_index=True)
    
copied_df2
# Out:
#                Player    GP
# 0           A.J. Cann    14
# 1          A.J. Derby     0
# 2      A.J. Jefferson     0
# 3         Aaron Davis     0
# 4          Adam Shead     0
# ..                ...   ...
# 630        Teez Tabor  10.0
# 631  TreDavious White  16.0
# 632    Treston DeCoud  10.0
# 633    William Likely   0.0
# 634      Xavier Woods  16.0
#
# [635 rows x 2 columns]

# %%
copied_df1.rename(columns={'Name': 'Player'}, inplace=True)
concatenated_copy_df = pd.concat([copied_df1, copied_df2], ignore_index=True)
concatenated_copy_df = concatenated_copy_df.fillna(0)
concatenated_copy_df
# Out:
#                  Player    GP
# 0         Braxston Cave   0.0
# 1        Brian Schwenke   9.0
# 2            Joe Madsen   0.0
# 3     Matt Stankiewitch   0.0
# 4         P.J. Lonergan   0.0
# ...                 ...   ...
# 1535         Teez Tabor  10.0
# 1536   TreDavious White  16.0
# 1537     Treston DeCoud  10.0
# 1538     William Likely   0.0
# 1539       Xavier Woods  16.0
#
# [1540 rows x 2 columns]

# %% [markdown]
# Note that here we will start our data cleaning
# - we will focus on cleaning up the combine pandas dataframe to include players name and the six combine workout that each player is evaulated upon
#
# - we will also focus on cleaning up the player pandas dataframe to include the players name and the games played

# %%
combine_data_2013 = combine_data_2013[['Player', '40yd', 'Vertical','Bench', 'BroadJump', '3Cone', 'Shuttle']]
combine_data_2014 = combine_data_2014[['Player', '40yd', 'Vertical','Bench', 'BroadJump', '3Cone', 'Shuttle']]
combine_data_2015 = combine_data_2015[['Player', '40yd', 'Vertical','Bench', 'BroadJump', '3Cone', 'Shuttle']]
combine_data_2016 = combine_data_2016[['Player', '40yd', 'Vertical','Bench', 'BroadJump', '3Cone', 'Shuttle']]
combine_data_2017 = combine_data_2017[['Player', '40yd', 'Vertical','Bench', 'BroadJump', '3Cone', 'Shuttle']]
combine_data_2015
# Out:
#              Player  40yd  Vertical  Bench  BroadJump  3Cone  Shuttle
# 0    Ameer Abdullah  4.60      42.5   24.0      130.0   6.79     3.95
# 1    Nelson Agholor  4.42       NaN   12.0        NaN    NaN      NaN
# 2         Jay Ajayi  4.57      39.0   19.0      121.0   7.10     4.10
# 3    Kwon Alexander  4.55      36.0   24.0      121.0   7.14     4.20
# 4      Mario Alford  4.43      34.0   13.0      121.0   6.64     4.07
# ..              ...   ...       ...    ...        ...    ...      ...
# 317  Jameis Winston  4.97      28.5    NaN      103.0   7.16     4.36
# 318      Cam Worthy  4.59       NaN   12.0        NaN    NaN      NaN
# 319     Gabe Wright  5.07      26.5   34.0      100.0   7.73     4.56
# 320     T.J. Yeldon  4.61      36.0   22.0      117.0   7.19     4.22
# 321     Zach Zenner  4.60      41.0   25.0      121.0   7.08     4.14
#
# [322 rows x 7 columns]

# %%
player_data_2013 = player_data_2013[['PlayerName','Games']]
player_data_2014 = player_data_2014[['PlayerName','Games']]
player_data_2015 = player_data_2015[['PlayerName','Games']]
player_data_2016 = player_data_2016[['PlayerName','Games']]
player_data_2017 = player_data_2017[['PlayerName','Games']]
player_data_2017
# Out:
#          PlayerName Games
# 0            Player     G
# 1     Todd Gurley*+    15
# 2    Le'Veon Bell*+    15
# 3      Kareem Hunt*    16
# 4     LeSean McCoy*    16
# ..              ...   ...
# 530    Nick Bellore    13
# 531    Justin Davis     4
# 532      Matt Hazel     4
# 533    Devante Mays     8
# 534   Kyle Williams    16
#
# [535 rows x 2 columns]

# %% [markdown]
# We will now drop any rows that have a NaN value. This is more specifically common in our NFL Combine data as there are participants who only do certain exercises and not all due to position, injury, etc. However just to make sure we will do the same for the player data as well.

# %% [markdown]
# NOTE
# We don't want to use a function like SimpleImputer from Scikit-Learn due to the fact that we don't want to assume what another combine players stats could be just because they are the most frequent

# %%
combine_data_2013 = combine_data_2013.dropna()
combine_data_2014 = combine_data_2014.dropna()
combine_data_2015 = combine_data_2015.dropna()
combine_data_2016 = combine_data_2016.dropna()
combine_data_2017 = combine_data_2017.dropna()

# %%
player_data_2013 = player_data_2013.dropna()
player_data_2014 = player_data_2014.dropna()
player_data_2015 = player_data_2015.dropna()
player_data_2016 = player_data_2016.dropna()
player_data_2017 = player_data_2017.dropna()
player_data_2017
# Out:
#          PlayerName Games
# 0            Player     G
# 1     Todd Gurley*+    15
# 2    Le'Veon Bell*+    15
# 3      Kareem Hunt*    16
# 4     LeSean McCoy*    16
# ..              ...   ...
# 530    Nick Bellore    13
# 531    Justin Davis     4
# 532      Matt Hazel     4
# 533    Devante Mays     8
# 534   Kyle Williams    16
#
# [535 rows x 2 columns]

# %% [markdown]
# We are now going to try and seperate our data into binary (1- played a snap 0-did not play a snap) in order to tell if a player that participated in the combine every played an NFL snap his rookie year
#
# But first we need to remove special characters from players names in the player data DF

# %%
player_data_2013['PlayerName'] = player_data_2013['PlayerName'].replace('[^a-zA-Z ]', '', regex=True)
player_data_2014['PlayerName'] = player_data_2014['PlayerName'].replace('[^a-zA-Z ]', '', regex=True)
player_data_2015['PlayerName'] = player_data_2015['PlayerName'].replace('[^a-zA-Z ]', '', regex=True)
player_data_2016['PlayerName'] = player_data_2016['PlayerName'].replace('[^a-zA-Z ]', '', regex=True)
player_data_2017['PlayerName'] = player_data_2017['PlayerName'].replace('[^a-zA-Z ]', '', regex=True)

# %%
merged_player_data = pd.concat([combine_data_2013,combine_data_2014,combine_data_2015,combine_data_2016,combine_data_2017], axis=0)
merged_player_data['PlayedGame'] = None
merged_player_data['Games'] = None

merged_data = pd.merge(concatenated_copy_df[['Player', 'GP']], merged_player_data, on='Player', how='left')

merged_data['Games'] = merged_data['GP']

merged_data['PlayedGame'] = (merged_data['GP'] > 0).astype(int)

merged_data.drop('GP', axis=1, inplace=True)

merged_player_data=merged_data.dropna()
merged_player_data
# Out:
#                  Player  40yd  Vertical  Bench  BroadJump  3Cone  Shuttle  \
# 1        Brian Schwenke  4.99      26.5   31.0      108.0   7.31     4.74
# 2            Joe Madsen  5.20      25.0   25.0       98.0   7.60     4.83
# 3     Matt Stankiewitch  5.43      24.0   27.0       92.0   7.90     4.96
# 5          T.J. Johnson  5.33      25.5   32.0       96.0   7.83     4.74
# 6      Travis Frederick  5.58      28.5   21.0       97.0   7.81     4.76
# ...                 ...   ...       ...    ...        ...    ...      ...
# 1534   Shaquill Griffin  4.38      38.5   17.0      132.0   6.87     4.14
# 1536    Sojourn Shelton  4.51      35.0   10.0      120.0   6.92     4.02
# 1537    Tedric Thompson  4.60      32.5   17.0      117.0   7.11     4.36
# 1539   TreDavious White  4.47      32.0   16.0      119.0   6.90     4.32
# 1542       Xavier Woods  4.54      33.5   19.0      122.0   6.72     4.13
#
#       PlayedGame  Games
# 1              1    9.0
# 2              0    0.0
# 3              0    0.0
# 5              0    0.0
# 6              1   16.0
# ...          ...    ...
# 1534           1   15.0
# 1536           0    0.0
# 1537           1    9.0
# 1539           1   16.0
# 1542           1   16.0
#
# [683 rows x 9 columns]

# %% [markdown]
# Now we will combine the PlayedGame column with our in our played_game_xxxx dataframe with our combine_data_xxxx dataframe based on the Players Name

# %% [markdown]
# Check to make sure that both columns are equal to 0 if one is equal to zero

# %%
result = merged_player_data[(merged_player_data['Games'] != 0) & (merged_player_data['PlayedGame'] == 0)]

if not result.empty:
    print("There are rows where both 'Games' and 'PlayedGame' are not zero.")
else:
    print("All rows have either 'Games' or 'PlayedGame' or both equal to zero.")
# Out:
# All rows have either 'Games' or 'PlayedGame' or both equal to zero.

# %%
result = merged_player_data[(merged_player_data['Games'] == 0) & (merged_player_data['PlayedGame'] != 0)]

if not result.empty:
    print("There are rows where both 'Games' and 'PlayedGame' are not zero.")
else:
    print("All rows have either 'Games' or 'PlayedGame' or both equal to zero.")
# Out:
# All rows have either 'Games' or 'PlayedGame' or both equal to zero.

# %% [markdown]
# Due to lack of complete data from where the Games and PlayedGame features are sourced from we will check every player with a 0 in there PlayedGame column to make sure that in our other dataset that contains partial data from the same season to see if they played.

# %%
T = merged_player_data['PlayedGame']
X = merged_player_data.loc[:, (merged_player_data.columns != "PlayedGame") & (merged_player_data.columns != "Player") & (merged_player_data.columns != "Games")]
T
# Out:
# 1       1
# 2       0
# 3       0
# 5       0
# 6       1
#        ..
# 1534    1
# 1536    0
# 1537    1
# 1539    1
# 1542    1
# Name: PlayedGame, Length: 683, dtype: int32

# %% [markdown]
# As we see here there is a clear class imbalance with merely more then double number 1 class vs 0 class

# %%
count_of_ones = merged_player_data['PlayedGame'].eq(1).sum()
count_of_zero = merged_player_data['PlayedGame'].eq(0).sum()
print("Number of times 1 appears in the column:", count_of_ones)
print("Number of times 0 appears in the column:", count_of_zero)
# Out:
# Number of times 1 appears in the column: 470
# Number of times 0 appears in the column: 213

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, t_train, t_test = train_test_split(X, T, test_size = .20, random_state = 0)


print(X.shape, X_train.shape, X_test.shape, t_train.shape, t_test.shape)
# Out:
# (683, 6) (546, 6) (137, 6) (546,) (137,)

# %%
from sklearn.linear_model import LinearRegression

np.random.seed(0)

#parameters for LinearRegression
# fit_intercept - bool - True or False - default: True
# Whether to calculate the intercept for this model. If set to False, no intercept will be used in calculations.
# normalize - bool - True or False - default: False
# If True, the regressors X will be normalized before regression by subtracting the mean and dividing by the l2-norm.
# copy_X - bool - True or False - default: True
# If True, X will be copied; else, it may be overwritten.
# n_jobs - int or None - default: None
# The number of jobs to use for the computation. None means 1 unless in a joblib.parallel_backend context. -1 means using all processors.

linearreg = LinearRegression()

# %% [markdown]
# Using a simple Linear Regression model it appears that our R^2 value is not very promising as we scored worse than a simple meaning model(score<0)
#
# Note that a score of 1 would be perfect
#
# lets see what this looks like when plotted

# %% [markdown]
# Now we will try the five models proposed in the paper our research is based off of "NFL Career Success as Predicted by NFL Scouting Combine"
# These models will be as follows
# Support Vector Machine
# Gradient Boosting
# Random Forest Decision Tree
# Multivariate Linear Regression
# Decision Tree

# %% [markdown]
# Support Vector Machine (come back to getting weird error)

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

#parameters for SVC  
# C - float - positive float
# Regularization parameter. The strength of the regularization is inversely proportional to C. Must be strictly positive.
# kernel - {'linear', 'poly', 'rbf', 'sigmoid', 'precomputed'} - default: 'rbf'
# Specifies the kernel type to be used in the algorithm. 'linear' uses a linear kernel, 'poly' uses a polynomial kernel, 'rbf' uses a radial basis function kernel, and 'sigmoid' uses a sigmoid kernel.
# degree - int - positive integer - applicable only to 'poly' kernel
# Degree of the polynomial kernel function ('poly'). Ignored by all other kernels.
# gamma - {'scale', 'auto'} or float - positive float - applicable to 'rbf', 'poly', and 'sigmoid' kernels
# Kernel coefficient for 'rbf', 'poly', and 'sigmoid'. If 'scale' is selected, it is calculated as 1 / (n_features * X.var()) and if 'auto', it uses 1 / n_features.
# probability - bool - True or False
# Whether to enable probability estimates. This must be enabled prior to calling `fit`, and it slows down the training process.

#create Support Vector Machine classifier
svm_classifier = SVC()

# %% [markdown]
# Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

#paramters for GradientBoostingClassifier
# n_estimators - int - positive integer
# The number of boosting stages to be run. It represents the number of weak learners (trees) to train.
# learning_rate - float - (0.0, 1.0]
# The step size shrinkage used to prevent overfitting. Lower values make the model more robust but require more trees.]
# max_depth - int or None - positive integer or None
# The maximum depth of the individual trees. Higher values can lead to overfitting.
# subsample - float - (0.0, 1.0]
# The fraction of samples used for fitting the individual base learners. Can prevent overfitting.

#create gradient boosting classifier
gb_classifier = GradientBoostingClassifier()

# %% [markdown]
# Random Forest Decision Tree

# %%
from sklearn.ensemble import RandomForestClassifier

#parameters for RandomForestClassifier
# n_estimators - int - positive integer
# The number of trees in the forest. It represents the number of base learners to train.
# max_depth - int or None - positive integer or None
# The maximum depth of the individual trees. Higher values can lead to overfitting.
# min_samples_split - int or float - positive integer or float (0.0, 1.0]
# The minimum number of samples required to split an internal node. If float, it represents the fraction of total samples.
# min_samples_leaf - int or float - positive integer or float (0.0, 1.0]
# The minimum number of samples required to be at a leaf node. If float, it represents the fraction of total samples.

#create random forest decision tree classifier
rf_classifier = RandomForestClassifier()

# %% [markdown]
# Multivariate Linear Regression

# %%
from sklearn.linear_model import LinearRegression

#parameters for LinearRegression
# fit_intercept - bool - True or False
# Whether to calculate the intercept for this model. If False, the model is forced to pass through the origin.
# normalize - bool - True or False
# If True, the regressors (features) will be normalized before regression. Useful when the magnitudes of variables differ significantly.
# n_jobs - int - integer or None
# The number of jobs to use for the computation. Set to -1 to use all available processors. Useful for large datasets.
# positive - bool - True or False
# When set to True, forces the coefficients to be positive. Useful when you have prior knowledge that the relationship is expected to be positive.

#create linear regression classifier
linear_model = LinearRegression()

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import mean_squared_error

# criterion - {'mse', 'friedman_mse', 'mae'} - default: 'mse'
# The function to measure the quality of a split. 'mse' is mean squared error, 'friedman_mse' is mean squared error with Friedman's improvement, and 'mae' is mean absolute error.
# max_depth - int - positive integer or None
# The maximum depth of the tree. Higher values can lead to overfitting.
# min_samples_split - int or float - positive integer or float (0.0, 1.0]
# The minimum number of samples required to split an internal node. If float, it represents the fraction of total samples.
# min_samples_leaf - int or float - positive integer or float (0.0, 1.0]
# The minimum number of samples required to be at a leaf node. If float, it represents the fraction of total samples.
# random_state - int, RandomState instance, or None
# Controls the randomness of the estimator. If int, it fixes the seed; if RandomState instance, it uses it; if None, randomness is determined by the RNG.

#crate decision tree classifier
tree_regressor = DecisionTreeClassifier()

# %% [markdown]
# Models not included in paper but want to consider to due high rate of probability classification with binary target values from personal research

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

#paramters that can be passed into LogisticRegression
# penalty - {'l1', 'l2', 'elasticnet', 'none'} - default: 'l2'
# Used to specify the norm used in the penalization. 'l1' and 'l2' are regularization terms, 'elasticnet' is a combination of both, and 'none' applies no regularization.
# C - float - positive float
# Inverse of regularization strength; smaller values specify stronger regularization. A lower C increases the regularization strength.
# max_iter - int - positive integer
# Maximum number of iterations for the solver to converge.
# solver - {'newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'} - default: 'lbfgs'
# Algorithm to use in the optimization problem. 'liblinear' is suitable for small datasets, 'lbfgs' and 'newton-cg' handle multinomial loss, 'sag' uses stochastic average gradient descent, and 'saga' is a variant of 'sag'.

#create logistic regression classifier

lr = LogisticRegression(max_iter=100)

# %% [markdown]
# k-Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier


#parameters that can be passed into KNeighborsClassifier
# n_neighbors - int - positive integer
# Number of neighbors to use for kneighbors queries. It defines the number of nearest neighbors considered when making predictions.
# weights - {'uniform', 'distance'} - default: 'uniform'
# Weight function used in prediction. 'uniform' assigns equal weights to all neighbors, while 'distance' assigns weights based on the inverse of the distance.
# algorithm - {'auto', 'ball_tree', 'kd_tree', 'brute'} - default: 'auto'
# Algorithm used to compute the nearest neighbors. 'auto' automatically selects the most appropriate algorithm based on the input data.
# p - int - 1 or 2
# Power parameter for the Minkowski metric. When p is set to 1, it corresponds to the Manhattan distance; when set to 2, it corresponds to the Euclidean distance.

#create K-Nearest Neighbor classifier
knn = KNeighborsClassifier()

# %% [markdown]
# Naive Bayesian

# %%
from sklearn.naive_bayes import GaussianNB

#parameters for GaussianNB
# priors - array-like, shape (n_classes,) - default: None
# Prior probabilities of the classes. If specified, the priors are not adjusted based on the data.
# var_smoothing - float - positive float
# Portion of the largest variance of all features added to variances for calculation stability. It represents the fraction of the largest variance to be added to the estimates for calculation stability.

#create Naive Bayesian classifier
bayes = GaussianNB()

# %% [markdown]
# Cross Validation and Accuracy Score
#
# What we will do here is loop through all of our models and use cross evaluation as a way to compare models. At end we will take the mean accuracy score.

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
# !pip install imbalanced-learn
from imblearn.over_sampling import SMOTE
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=2) 
X_pca = pca.fit_transform(X_scaled)

T = T.astype('int')
X_train, X_test, t_train, t_test = train_test_split(X_pca, T, test_size=0.20, random_state=0)

smote = SMOTE(sampling_strategy='auto', random_state=42)

X_train, t_train = smote.fit_resample(X_train, t_train)

models = [["K-Nearest Neighbor",knn],["Naive Bayesian", bayes],["Support Vector Machine",svm_classifier],["Gradient Boosting",gb_classifier],["Random Forest Decision Tree",rf_classifier],["Decision Tree",tree_regressor],["Logistic Regression",lr]]

#loop through each model in models array
for model in models:
    #calculate accuracy score using cross-validation
    cv_accuracy = cross_val_score(model[1], X_train, t_train, cv=10, scoring='accuracy')
    avg_accuracy = np.mean(cv_accuracy)
    
    #model[1].fit(X_train, t_train)
    #t_pred = model[1].predict(X_test)
    #avg_accuracy = accuracy_score(t_test, t_pred)
    
    print("Model: ", model[0], "Average Accuracy: ", avg_accuracy)
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\davis\anaconda3\lib\site-packages (0.12.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\davis\anaconda3\lib\site-packages (from imbalanced-learn) (1.22.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\davis\anaconda3\lib\site-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\davis\anaconda3\lib\site-packages (from imbalanced-learn) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\davis\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\davis\anaconda3\lib\site-packages (from imbalanced-learn) (1.3.2)
# Model:  K-Nearest Neighbor Average Accuracy:  0.656918918918919
# Model:  Naive Bayesian Average Accuracy:  0.6031351351351352
# Model:  Support Vector Machine Average Accuracy:  0.6205945945945945
# Model:  Gradient Boosting Average Accuracy:  0.6354594594594595
# Model:  Random Forest Decision Tree Average Accuracy:  0.6809009009009009
# Model:  Decision Tree Average Accuracy:  0.6689549549549549
# Model:  Logistic Regression Average Accuracy:  0.5950450450450451

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=2) 
X_pca = pca.fit_transform(X_scaled)

T = T.astype('int')
X_train, X_test, t_train, t_test = train_test_split(X_pca, T, test_size=0.20, random_state=0)

smote = SMOTE(sampling_strategy='auto', random_state=32)

models = [["K-Nearest Neighbor",knn],["Naive Bayesian", bayes],["Support Vector Machine",svm_classifier],["Gradient Boosting",gb_classifier],["Random Forest Decision Tree",rf_classifier],["Decision Tree",tree_regressor],["Logistic Regression",lr]]

#loop through each model in models array
for model_name, model_instance in models:
    print("{:=^50s}".format(model_name))
    
    #fit the model on the training data
    model_instance.fit(X_train, t_train)
    
    #make predictions on the test data
    y_test = model_instance.predict(X_test)
    
    #used to evalue scores of binary classifiers
    mcc_score = matthews_corrcoef(t_test, y_test)
    print("MCC:",mcc_score)
    
    #print classification report
    cm_report = classification_report(t_test, y_test)
    print(cm_report)
    
    #generate confusion matrix
    cm = confusion_matrix(t_test, y_test)
    
    #display confusion matrix
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(t_test))
    disp.plot(cmap=plt.cm.magma)
    plt.title('Confusion Matrix for ' + model_name) 
    plt.show()
# Out:
# ================K-Nearest Neighbor================
# MCC: 0.04507101550456716
#               precision    recall  f1-score   support
#
#            0       0.33      0.23      0.27        40
#            1       0.72      0.81      0.76        97
#
#     accuracy                           0.64       137
#    macro avg       0.53      0.52      0.52       137
# weighted avg       0.61      0.64      0.62       137
# ==================Naive Bayesian==================
# MCC: 0.08497523390969203
#               precision    recall  f1-score   support
#
#            0       0.42      0.12      0.19        40
#            1       0.72      0.93      0.81        97
#
#     accuracy                           0.69       137
#    macro avg       0.57      0.53      0.50       137
# weighted avg       0.63      0.69      0.63       137
# ==============Support Vector Machine==============
# MCC: 0.05568998626725217
#               precision    recall  f1-score   support
#
#            0       0.50      0.03      0.05        40
#            1       0.71      0.99      0.83        97
#
#     accuracy                           0.71       137
#    macro avg       0.61      0.51      0.44       137
# weighted avg       0.65      0.71      0.60       137
# ================Gradient Boosting=================
# MCC: 0.21695583211306932
#               precision    recall  f1-score   support
#
#            0       0.52      0.28      0.36        40
#            1       0.75      0.90      0.82        97
#
#     accuracy                           0.72       137
#    macro avg       0.64      0.59      0.59       137
# weighted avg       0.68      0.72      0.68       137
# ===========Random Forest Decision Tree============
# MCC: 0.23527023892245752
#               precision    recall  f1-score   support
#
#            0       0.46      0.45      0.46        40
#            1       0.78      0.78      0.78        97
#
#     accuracy                           0.69       137
#    macro avg       0.62      0.62      0.62       137
# weighted avg       0.68      0.69      0.68       137
# ==================Decision Tree===================
# MCC: 0.36992297791002415
#               precision    recall  f1-score   support
#
#            0       0.49      0.70      0.58        40
#            1       0.85      0.70      0.77        97
#
#     accuracy                           0.70       137
#    macro avg       0.67      0.70      0.67       137
# weighted avg       0.75      0.70      0.71       137
# ===============Logistic Regression================
# MCC: -0.058980722586181686
#               precision    recall  f1-score   support
#
#            0       0.17      0.03      0.04        40
#            1       0.70      0.95      0.81        97
#
#     accuracy                           0.68       137
#    macro avg       0.43      0.49      0.43       137
# weighted avg       0.55      0.68      0.58       137

# %% [markdown]
# Now lets look at our model from a regression standpoint

# %%
T = merged_player_data['Games']
X = merged_player_data.loc[:, (merged_player_data.columns != "PlayedGame") & (merged_player_data.columns != "Player") & (merged_player_data.columns != "Games")]
X
# Out:
#       40yd  Vertical  Bench  BroadJump  3Cone  Shuttle
# 1     4.99      26.5   31.0      108.0   7.31     4.74
# 2     5.20      25.0   25.0       98.0   7.60     4.83
# 3     5.43      24.0   27.0       92.0   7.90     4.96
# 5     5.33      25.5   32.0       96.0   7.83     4.74
# 6     5.58      28.5   21.0       97.0   7.81     4.76
# ...    ...       ...    ...        ...    ...      ...
# 1534  4.38      38.5   17.0      132.0   6.87     4.14
# 1536  4.51      35.0   10.0      120.0   6.92     4.02
# 1537  4.60      32.5   17.0      117.0   7.11     4.36
# 1539  4.47      32.0   16.0      119.0   6.90     4.32
# 1542  4.54      33.5   19.0      122.0   6.72     4.13
#
# [683 rows x 6 columns]

# %%
from sklearn.model_selection import cross_validate

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=2) 
X_pca = pca.fit_transform(X_scaled)

T = T.astype('int')
X_train, X_test, t_train, t_test = train_test_split(X_pca, T, test_size=0.20, random_state=0)

models = [["K-Nearest Neighbor",knn],["Naive Bayesian", bayes],["Support Vector Machine",svm_classifier],["Gradient Boosting",gb_classifier],["Random Forest Decision Tree",rf_classifier],["Decision Tree",tree_regressor],["Logistic Regression",lr],["Linear Regression",linearreg]]

#loop through each model in models array
for model in models:
    #calculate accuracy score using 10-fold cross-validation
    mod = model[1].fit(X_train,t_train)
    rootMeanSquaredError = cross_validate(mod, X_train, t_train, cv=10, scoring=['neg_root_mean_squared_error'],return_train_score=True)
    convertedRMSE = np.abs(np.mean(rootMeanSquaredError['test_neg_root_mean_squared_error']))
    
    print("Model: ", model[0], "Average Accuracy: ", convertedRMSE)
# Out:
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 6 members, which is less than n_splits=10.
#   warnings.warn(
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 6 members, which is less than n_splits=10.
#   warnings.warn(
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 6 members, which is less than n_splits=10.
#   warnings.warn(
# Model:  K-Nearest Neighbor Average Accuracy:  9.500005365049486
# Model:  Naive Bayesian Average Accuracy:  9.368751371469084
# Model:  Support Vector Machine Average Accuracy:  9.64692881568864
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 6 members, which is less than n_splits=10.
#   warnings.warn(
# Model:  Gradient Boosting Average Accuracy:  9.018585337673578
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 6 members, which is less than n_splits=10.
#   warnings.warn(
# Model:  Random Forest Decision Tree Average Accuracy:  8.878506412014815
# Model:  Decision Tree Average Accuracy:  8.565445075956754
# Model:  Logistic Regression Average Accuracy:  9.238618799623339
# Model:  Linear Regression Average Accuracy:  6.460627074218465
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 6 members, which is less than n_splits=10.
#   warnings.warn(
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 6 members, which is less than n_splits=10.
#   warnings.warn(

# %% [markdown]
# Now lets try and improve our model by feeding it different data.
#
# Since some positions should/shouldn't have certains combine statistics. For example a lineman is not expected to run a 4.4 40 yard dash. Therefore do we need to add positions as an attribute that our model is run on. Lets test it.

# %%
#hashmap that will coordinate the numerical number assigned to each position group

#O-Line: 0
#D-Line DT/DE: 1
#Edge: 2
#QB: 3
#TE: 4
#WR: 5
#RB: 6
#CB/S: 7

position_map = {"OT":0,
               "CB":1,
               "WR":2,
               "P":3,
               "DE":4,
               "RB":5,
               "OG":6,
               "FB":7,
               "ILB":8,
               "TE":9,
               "OLB":10,
               "S":11,
               "K":12,
               "EDGE":13,
               "C":14,
               "DT":15,
               "QB":16,
               "DB":17,
               "DL":18,
               "LB":19,
               "OL":20,
               "LS":21}

# %%
combine_data_2013 = pd.read_csv('../data/combine_data_2013.csv')
combine_data_2014 = pd.read_csv('../data/combine_data_2014.csv')
combine_data_2015 = pd.read_csv('../data/combine_data_2015.csv')
combine_data_2016 = pd.read_csv('../data/combine_data_2016.csv')
combine_data_2017 = pd.read_csv('../data/combine_data_2017.csv')

# %%
combine_data_2013 = combine_data_2013[['Player','Pos']]
combine_data_2014= combine_data_2014[['Player','Pos']]
combine_data_2015= combine_data_2015[['Player','Pos']]
combine_data_2016= combine_data_2016[['Player','Pos']]
combine_data_2017= combine_data_2017[['Player','Pos']]
combine_data_2017
# Out:
#                   Player Pos
# 0            Jamal Adams   S
# 1       Montravius Adams  DT
# 2           Rodney Adams  WR
# 3       Quincy Adeboyejo  WR
# 4            Brian Allen  CB
# ..                   ...  ..
# 322         Jesus Wilson  WR
# 323        Quincy Wilson  CB
# 324  Ahkello Witherspoon  CB
# 325         Xavier Woods   S
# 326        Chris Wormley  DT
#
# [327 rows x 2 columns]

# %%
# Combine all combine_data DataFrames
combined_data = pd.concat([combine_data_2013,combine_data_2014,combine_data_2015,combine_data_2016,combine_data_2017], axis=0, ignore_index=True)

# Merge combined_data with merged_player_data
merged_player_data_with_pos = pd.merge(merged_player_data, combined_data, on='Player', how='left')

merged_player_data_with_pos = merged_player_data_with_pos.drop_duplicates()
merged_player_data_with_pos = merged_player_data_with_pos.reset_index(drop=True)
merged_player_data_with_pos = merged_player_data_with_pos.dropna()

# Print the resulting DataFrame
print(merged_player_data_with_pos[['Player','Pos']])
# Out:
#                 Player Pos
# 0       Brian Schwenke   C
# 1           Joe Madsen   C
# 2    Matt Stankiewitch   C
# 3         T.J. Johnson   C
# 4     Travis Frederick   C
# ..                 ...  ..
# 632   Shaquill Griffin  CB
# 633    Sojourn Shelton  CB
# 634    Tedric Thompson   S
# 635   TreDavious White  CB
# 636       Xavier Woods   S
#
# [637 rows x 2 columns]

# %%
merged_player_data_with_pos['Pos'] = merged_player_data_with_pos['Pos'].map(lambda x: position_map.get(x, x))
print(merged_player_data_with_pos)
# Out:
#                 Player  40yd  Vertical  Bench  BroadJump  3Cone  Shuttle  \
# 0       Brian Schwenke  4.99      26.5   31.0      108.0   7.31     4.74
# 1           Joe Madsen  5.20      25.0   25.0       98.0   7.60     4.83
# 2    Matt Stankiewitch  5.43      24.0   27.0       92.0   7.90     4.96
# 3         T.J. Johnson  5.33      25.5   32.0       96.0   7.83     4.74
# 4     Travis Frederick  5.58      28.5   21.0       97.0   7.81     4.76
# ..                 ...   ...       ...    ...        ...    ...      ...
# 632   Shaquill Griffin  4.38      38.5   17.0      132.0   6.87     4.14
# 633    Sojourn Shelton  4.51      35.0   10.0      120.0   6.92     4.02
# 634    Tedric Thompson  4.60      32.5   17.0      117.0   7.11     4.36
# 635   TreDavious White  4.47      32.0   16.0      119.0   6.90     4.32
# 636       Xavier Woods  4.54      33.5   19.0      122.0   6.72     4.13
#
#      PlayedGame  Games  Pos
# 0             1    9.0   14
# 1             0    0.0   14
# 2             0    0.0   14
# 3             0    0.0   14
# 4             1   16.0   14
# ..          ...    ...  ...
# 632           1   15.0    1
# 633           0    0.0    1
# 634           1    9.0   11
# 635           1   16.0    1
# 636           1   16.0   11
#
# [637 rows x 10 columns]

# %%
T = merged_player_data_with_pos['PlayedGame']
X = merged_player_data_with_pos.loc[:, (merged_player_data_with_pos.columns != "Games") & (merged_player_data_with_pos.columns != "PlayedGame") & (merged_player_data_with_pos.columns != "Player") & (merged_player_data_with_pos.columns != "Pos_x") & (merged_player_data_with_pos.columns != "Pos_y")]
X
# Out:
#      40yd  Vertical  Bench  BroadJump  3Cone  Shuttle  Pos
# 0    4.99      26.5   31.0      108.0   7.31     4.74   14
# 1    5.20      25.0   25.0       98.0   7.60     4.83   14
# 2    5.43      24.0   27.0       92.0   7.90     4.96   14
# 3    5.33      25.5   32.0       96.0   7.83     4.74   14
# 4    5.58      28.5   21.0       97.0   7.81     4.76   14
# ..    ...       ...    ...        ...    ...      ...  ...
# 632  4.38      38.5   17.0      132.0   6.87     4.14    1
# 633  4.51      35.0   10.0      120.0   6.92     4.02    1
# 634  4.60      32.5   17.0      117.0   7.11     4.36   11
# 635  4.47      32.0   16.0      119.0   6.90     4.32    1
# 636  4.54      33.5   19.0      122.0   6.72     4.13   11
#
# [637 rows x 7 columns]

# %% [markdown]
# Classification Accuracy Given Player Position

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=2) 
X_pca = pca.fit_transform(X_scaled)

T = T.astype('int')
X_train, X_test, t_train, t_test = train_test_split(X_pca, T, test_size=0.20, random_state=0)

smote = SMOTE(sampling_strategy='auto', random_state=42)
X_train, t_train = smote.fit_resample(X_train, t_train)

models = [["K-Nearest Neighbor",knn],["Naive Bayesian", bayes],["Support Vector Machine",svm_classifier],["Gradient Boosting",gb_classifier],["Random Forest Decision Tree",rf_classifier],["Decision Tree",tree_regressor],["Logistic Regression",lr]]

#loop through each model in models array
for model in models:
    #calculate accuracy score using 10-fold cross-validation
    cv_accuracy = cross_val_score(model[1], X_train, t_train, cv=10, scoring='accuracy')
    avg_accuracy = np.mean(cv_accuracy)
    
    print("Model: ", model[0], "Average Accuracy: ", avg_accuracy)
# Out:
# Model:  K-Nearest Neighbor Average Accuracy:  0.6525672877846791
# Model:  Naive Bayesian Average Accuracy:  0.6134989648033127
# Model:  Support Vector Machine Average Accuracy:  0.6206211180124223
# Model:  Gradient Boosting Average Accuracy:  0.6238095238095238
# Model:  Random Forest Decision Tree Average Accuracy:  0.6511594202898552
# Model:  Decision Tree Average Accuracy:  0.6395859213250518
# Model:  Logistic Regression Average Accuracy:  0.6119668737060041

# %% [markdown]
# Confusion Matrix

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay,matthews_corrcoef
import numpy as np
import matplotlib.pyplot as plt

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=2) 
X_pca = pca.fit_transform(X_scaled)

T = T.astype('int')
X_train, X_test, t_train, t_test = train_test_split(X_pca, T, test_size=0.20, random_state=0)

smote = SMOTE(sampling_strategy='auto', random_state=32)

models = [["K-Nearest Neighbor",knn],["Naive Bayesian", bayes],["Support Vector Machine",svm_classifier],["Gradient Boosting",gb_classifier],["Random Forest Decision Tree",rf_classifier],["Decision Tree",tree_regressor],["Logistic Regression",lr]]

#loop through each model in models array
for model_name, model_instance in models:
    print("{:=^50s}".format(model_name))
    
    #fit the model on the training data
    model_instance.fit(X_train, t_train)
    
    #make predictions on the test data
    y_test = model_instance.predict(X_test)
    
    #used to evalue scores of binary classifiers
    mcc_score = matthews_corrcoef(t_test, y_test)
    print("MCC:",mcc_score)
    
    #print classification report
    cm_report = classification_report(t_test, y_test)
    print(cm_report)
    
    #generate confusion matrix
    cm = confusion_matrix(t_test, y_test)
    
    #display confusion matrix
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(t_test))
    disp.plot(cmap=plt.cm.magma)
    plt.title('Confusion Matrix for ' + model_name) 
    plt.show()
# Out:
# ================K-Nearest Neighbor================
# MCC: 0.22453896554264371
#               precision    recall  f1-score   support
#
#            0       0.50      0.36      0.42        39
#            1       0.75      0.84      0.79        89
#
#     accuracy                           0.70       128
#    macro avg       0.62      0.60      0.61       128
# weighted avg       0.67      0.70      0.68       128
# ==================Naive Bayesian==================
# MCC: 0.12352978859525167
#               precision    recall  f1-score   support
#
#            0       0.50      0.13      0.20        39
#            1       0.71      0.94      0.81        89
#
#     accuracy                           0.70       128
#    macro avg       0.61      0.54      0.51       128
# weighted avg       0.65      0.70      0.63       128
# ==============Support Vector Machine==============
# MCC: 0.0
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        39
#            1       0.70      1.00      0.82        89
#
#     accuracy                           0.70       128
#    macro avg       0.35      0.50      0.41       128
# weighted avg       0.48      0.70      0.57       128
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ================Gradient Boosting=================
# MCC: 0.2993177370889261
#               precision    recall  f1-score   support
#
#            0       0.55      0.44      0.49        39
#            1       0.77      0.84      0.81        89
#
#     accuracy                           0.72       128
#    macro avg       0.66      0.64      0.65       128
# weighted avg       0.70      0.72      0.71       128
# ===========Random Forest Decision Tree============
# MCC: 0.18045733270201025
#               precision    recall  f1-score   support
#
#            0       0.45      0.36      0.40        39
#            1       0.74      0.81      0.77        89
#
#     accuracy                           0.67       128
#    macro avg       0.60      0.58      0.59       128
# weighted avg       0.65      0.67      0.66       128
# ==================Decision Tree===================
# MCC: 0.18802519977057536
#               precision    recall  f1-score   support
#
#            0       0.42      0.49      0.45        39
#            1       0.76      0.71      0.73        89
#
#     accuracy                           0.64       128
#    macro avg       0.59      0.60      0.59       128
# weighted avg       0.66      0.64      0.65       128
# ===============Logistic Regression================
# MCC: 0.08350333747444164
#               precision    recall  f1-score   support
#
#            0       0.44      0.10      0.17        39
#            1       0.71      0.94      0.81        89
#
#     accuracy                           0.69       128
#    macro avg       0.58      0.52      0.49       128
# weighted avg       0.63      0.69      0.61       128

# %% [markdown]
# It seems as if the Support Vector Machine model has one of the best accuracies compared to any other model. Lets try and see if we can fine tune by using GridSearchCV to see if we can find the best hyperparemters for our model.

# %%
from sklearn.model_selection import GridSearchCV

#parameters for Random Forest
# n_estimators: int, default=100
# The number of trees in the forest.
# max_depth: int, default=None
# The maximum depth of the trees. 
# If None, then nodes are expanded until all leaves are pure or until all leaves contain less than min_samples_split samples.
# min_samples_split: int or float, default=2
# The minimum number of samples required to split an internal node.


param_grid = {'class_weight': [{0: w0, 1: w1} for w0 in [1, 2, 3] for w1 in [1, 2, 3]]}

grid_search = GridSearchCV(LogisticRegression(max_iter=1000), param_grid, cv=10)
grid_search.fit(X_train, t_train)
#print("Grid search results:", grid_search.cv_results_)
print("Best parameters:", grid_search.best_params_)

#evaluate the best model on the test set
best_model = grid_search.best_estimator_
accuracy = best_model.score(X_test, t_test)
print("Test accuracy:", accuracy)
# Out:
# Best parameters: {'class_weight': {0: 1, 1: 3}}
# Test accuracy: 0.6953125

# %% [markdown]
# Hyperparemter values shown in graph

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator

# Extract parameter values
class_weights = grid_search.cv_results_['params']
accuracies = grid_search.cv_results_['mean_test_score']
std_accuracies = grid_search.cv_results_['std_test_score']

# Format parameter names
param_names = [f"{w[0]}_{w[1]}" for w in [p['class_weight'] for p in class_weights]]

plt.figure(figsize=(10, 8))

# Plot mean test scores
plt.errorbar(param_names, accuracies, yerr=std_accuracies, fmt='o-', capsize=5)

plt.xlabel("Class Weights")
plt.ylabel("CV Accuracy")
plt.title("Cross-Validation Accuracy for Different Class Weights")

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Lets now look at Root Mean Square Error of our models to see if we can predict the number of snaps a player will player in a season rather then just will a player play in a season.

# %%
T = merged_player_data_with_pos['Games']
X = merged_player_data_with_pos.loc[:, (merged_player_data_with_pos.columns != "Games") & (merged_player_data_with_pos.columns != "PlayedGame") & (merged_player_data_with_pos.columns != "Player") & (merged_player_data_with_pos.columns != "Pos_x") & (merged_player_data_with_pos.columns != "Pos_y")]
X
# Out:
#      40yd  Vertical  Bench  BroadJump  3Cone  Shuttle  Pos
# 0    4.99      26.5   31.0      108.0   7.31     4.74   14
# 1    5.20      25.0   25.0       98.0   7.60     4.83   14
# 2    5.43      24.0   27.0       92.0   7.90     4.96   14
# 3    5.33      25.5   32.0       96.0   7.83     4.74   14
# 4    5.58      28.5   21.0       97.0   7.81     4.76   14
# ..    ...       ...    ...        ...    ...      ...  ...
# 632  4.38      38.5   17.0      132.0   6.87     4.14    1
# 633  4.51      35.0   10.0      120.0   6.92     4.02    1
# 634  4.60      32.5   17.0      117.0   7.11     4.36   11
# 635  4.47      32.0   16.0      119.0   6.90     4.32    1
# 636  4.54      33.5   19.0      122.0   6.72     4.13   11
#
# [637 rows x 7 columns]

# %%
from sklearn.linear_model import LinearRegression

linearreg = LinearRegression()

# %%
from sklearn.model_selection import cross_validate

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=2) 
X_pca = pca.fit_transform(X_scaled)

T = T.astype('int')
X_train, X_test, t_train, t_test = train_test_split(X_pca, T, test_size=0.20, random_state=0)

models = [["K-Nearest Neighbor",knn],["Naive Bayesian", bayes],["Support Vector Machine",svm_classifier],["Gradient Boosting",gb_classifier],["Random Forest Decision Tree",rf_classifier],["Decision Tree",tree_regressor],["Logistic Regression",lr],["Linear Regression",linearreg]]

#loop through each model in models array
for model in models:
    #calculate accuracy score using 10-fold cross-validation
    mod = model[1].fit(X_train,t_train)
    rootMeanSquaredError = cross_validate(mod, X_train, t_train, cv=10, scoring=['neg_root_mean_squared_error'],return_train_score=True)
    convertedRMSE = np.abs(np.mean(rootMeanSquaredError['test_neg_root_mean_squared_error']))
    
    print("Model: ", model[0], "Average Accuracy: ", convertedRMSE)
# Out:
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 5 members, which is less than n_splits=10.
#   warnings.warn(
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 5 members, which is less than n_splits=10.
#   warnings.warn(
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 5 members, which is less than n_splits=10.
#   warnings.warn(
# Model:  K-Nearest Neighbor Average Accuracy:  9.470147034193642
# Model:  Naive Bayesian Average Accuracy:  9.130793152573208
# Model:  Support Vector Machine Average Accuracy:  9.338195772445047
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 5 members, which is less than n_splits=10.
#   warnings.warn(
# Model:  Gradient Boosting Average Accuracy:  9.485000128277099
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 5 members, which is less than n_splits=10.
#   warnings.warn(
# Model:  Random Forest Decision Tree Average Accuracy:  9.298059129224496
# Model:  Decision Tree Average Accuracy:  9.155922759202832
# Model:  Logistic Regression Average Accuracy:  9.055276034523228
# Model:  Linear Regression Average Accuracy:  6.372903396489045
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 5 members, which is less than n_splits=10.
#   warnings.warn(
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 5 members, which is less than n_splits=10.
#   warnings.warn(

# %%
combine_data_2013 = pd.read_csv('../data/combine_data_2013.csv')
combine_data_2014 = pd.read_csv('../data/combine_data_2014.csv')
combine_data_2015 = pd.read_csv('../data/combine_data_2015.csv')
combine_data_2016 = pd.read_csv('../data/combine_data_2016.csv')
combine_data_2017 = pd.read_csv('../data/combine_data_2017.csv')
combine_data_frames = [combine_data_2013, combine_data_2014, combine_data_2015, combine_data_2016, combine_data_2017]

player_height_weight = pd.DataFrame(columns=['Player', 'Ht', 'Wt'])

for df in combine_data_frames:
    player_height_weight = pd.concat([player_height_weight, df[['Player', 'Ht', 'Wt']]], ignore_index=True)

merged_player_data_with_pos = pd.merge(merged_player_data_with_pos, player_height_weight, on='Player', how='left')
merged_player_data_with_pos
# Out:
#                 Player  40yd  Vertical  Bench  BroadJump  3Cone  Shuttle  \
# 0       Brian Schwenke  4.99      26.5   31.0      108.0   7.31     4.74
# 1           Joe Madsen  5.20      25.0   25.0       98.0   7.60     4.83
# 2    Matt Stankiewitch  5.43      24.0   27.0       92.0   7.90     4.96
# 3         T.J. Johnson  5.33      25.5   32.0       96.0   7.83     4.74
# 4     Travis Frederick  5.58      28.5   21.0       97.0   7.81     4.76
# ..                 ...   ...       ...    ...        ...    ...      ...
# 652   Shaquill Griffin  4.38      38.5   17.0      132.0   6.87     4.14
# 653    Sojourn Shelton  4.51      35.0   10.0      120.0   6.92     4.02
# 654    Tedric Thompson  4.60      32.5   17.0      117.0   7.11     4.36
# 655   TreDavious White  4.47      32.0   16.0      119.0   6.90     4.32
# 656       Xavier Woods  4.54      33.5   19.0      122.0   6.72     4.13
#
#      PlayedGame  Games  Pos    Ht   Wt
# 0             1    9.0   14   6-3  314
# 1             0    0.0   14   6-3  310
# 2             0    0.0   14   6-3  302
# 3             0    0.0   14   6-4  310
# 4             1   16.0   14   6-4  312
# ..          ...    ...  ...   ...  ...
# 652           1   15.0    1   6-0  194
# 653           0    0.0    1   5-9  177
# 654           1    9.0   11   6-0  204
# 655           1   16.0    1  5-11  192
# 656           1   16.0   11  5-11  197
#
# [657 rows x 12 columns]

# %%
merged_player_data_with_pos
merged_player_data_with_pos = merged_player_data_with_pos.drop_duplicates(subset=['Player', 'Ht', 'Wt'])
merged_player_data_with_pos = merged_player_data_with_pos.reset_index(drop=True)
merged_player_data_with_pos
# Out:
#                 Player  40yd  Vertical  Bench  BroadJump  3Cone  Shuttle  \
# 0       Brian Schwenke  4.99      26.5   31.0      108.0   7.31     4.74
# 1           Joe Madsen  5.20      25.0   25.0       98.0   7.60     4.83
# 2    Matt Stankiewitch  5.43      24.0   27.0       92.0   7.90     4.96
# 3         T.J. Johnson  5.33      25.5   32.0       96.0   7.83     4.74
# 4     Travis Frederick  5.58      28.5   21.0       97.0   7.81     4.76
# ..                 ...   ...       ...    ...        ...    ...      ...
# 616   Shaquill Griffin  4.38      38.5   17.0      132.0   6.87     4.14
# 617    Sojourn Shelton  4.51      35.0   10.0      120.0   6.92     4.02
# 618    Tedric Thompson  4.60      32.5   17.0      117.0   7.11     4.36
# 619   TreDavious White  4.47      32.0   16.0      119.0   6.90     4.32
# 620       Xavier Woods  4.54      33.5   19.0      122.0   6.72     4.13
#
#      PlayedGame  Games  Pos    Ht   Wt
# 0             1    9.0   14   6-3  314
# 1             0    0.0   14   6-3  310
# 2             0    0.0   14   6-3  302
# 3             0    0.0   14   6-4  310
# 4             1   16.0   14   6-4  312
# ..          ...    ...  ...   ...  ...
# 616           1   15.0    1   6-0  194
# 617           0    0.0    1   5-9  177
# 618           1    9.0   11   6-0  204
# 619           1   16.0    1  5-11  192
# 620           1   16.0   11  5-11  197
#
# [621 rows x 12 columns]

# %%
merged_player_data_with_pos['Ht'] = merged_player_data_with_pos['Ht'].str.replace('-', '.')
print(merged_player_data_with_pos)
# Out:
#                 Player  40yd  Vertical  Bench  BroadJump  3Cone  Shuttle  \
# 0       Brian Schwenke  4.99      26.5   31.0      108.0   7.31     4.74
# 1           Joe Madsen  5.20      25.0   25.0       98.0   7.60     4.83
# 2    Matt Stankiewitch  5.43      24.0   27.0       92.0   7.90     4.96
# 3         T.J. Johnson  5.33      25.5   32.0       96.0   7.83     4.74
# 4     Travis Frederick  5.58      28.5   21.0       97.0   7.81     4.76
# ..                 ...   ...       ...    ...        ...    ...      ...
# 616   Shaquill Griffin  4.38      38.5   17.0      132.0   6.87     4.14
# 617    Sojourn Shelton  4.51      35.0   10.0      120.0   6.92     4.02
# 618    Tedric Thompson  4.60      32.5   17.0      117.0   7.11     4.36
# 619   TreDavious White  4.47      32.0   16.0      119.0   6.90     4.32
# 620       Xavier Woods  4.54      33.5   19.0      122.0   6.72     4.13
#
#      PlayedGame  Games  Pos    Ht   Wt
# 0             1    9.0   14   6.3  314
# 1             0    0.0   14   6.3  310
# 2             0    0.0   14   6.3  302
# 3             0    0.0   14   6.4  310
# 4             1   16.0   14   6.4  312
# ..          ...    ...  ...   ...  ...
# 616           1   15.0    1   6.0  194
# 617           0    0.0    1   5.9  177
# 618           1    9.0   11   6.0  204
# 619           1   16.0    1  5.11  192
# 620           1   16.0   11  5.11  197
#
# [621 rows x 12 columns]

# %%
T = merged_player_data_with_pos['PlayedGame']
X = merged_player_data_with_pos.loc[:, (merged_player_data_with_pos.columns != "Games") & (merged_player_data_with_pos.columns != "PlayedGame") & (merged_player_data_with_pos.columns != "Player") & (merged_player_data_with_pos.columns != "Pos_x") & (merged_player_data_with_pos.columns != "Pos_y")]
X
# Out:
#      40yd  Vertical  Bench  BroadJump  3Cone  Shuttle  Pos    Ht   Wt
# 0    4.99      26.5   31.0      108.0   7.31     4.74   14   6.3  314
# 1    5.20      25.0   25.0       98.0   7.60     4.83   14   6.3  310
# 2    5.43      24.0   27.0       92.0   7.90     4.96   14   6.3  302
# 3    5.33      25.5   32.0       96.0   7.83     4.74   14   6.4  310
# 4    5.58      28.5   21.0       97.0   7.81     4.76   14   6.4  312
# ..    ...       ...    ...        ...    ...      ...  ...   ...  ...
# 616  4.38      38.5   17.0      132.0   6.87     4.14    1   6.0  194
# 617  4.51      35.0   10.0      120.0   6.92     4.02    1   5.9  177
# 618  4.60      32.5   17.0      117.0   7.11     4.36   11   6.0  204
# 619  4.47      32.0   16.0      119.0   6.90     4.32    1  5.11  192
# 620  4.54      33.5   19.0      122.0   6.72     4.13   11  5.11  197
#
# [621 rows x 9 columns]

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=4) 
X_pca = pca.fit_transform(X_scaled)

T = T.astype('int')
X_train, X_test, t_train, t_test = train_test_split(X_pca, T, test_size=0.20, random_state=0)

smote = SMOTE(sampling_strategy='auto', random_state=42)
X_train, t_train = smote.fit_resample(X_train, t_train)
models = [["K-Nearest Neighbor",knn],["Naive Bayesian", bayes],["Support Vector Machine",svm_classifier],["Gradient Boosting",gb_classifier],["Random Forest Decision Tree",rf_classifier],["Decision Tree",tree_regressor],["Logistic Regression",lr]]

#loop through each model in models array
for model in models:
    #calculate accuracy score using 10-fold cross-validation
    cv_accuracy = cross_val_score(model[1], X_train, t_train, cv=10, scoring='accuracy')
    avg_accuracy = np.mean(cv_accuracy)
    
    print("Model: ", model[0], "Average Accuracy: ", avg_accuracy)
# Out:
# Model:  K-Nearest Neighbor Average Accuracy:  0.6465400271370422
# Model:  Naive Bayesian Average Accuracy:  0.6057440072365446
# Model:  Support Vector Machine Average Accuracy:  0.620805065581185
# Model:  Gradient Boosting Average Accuracy:  0.6329036635006784
# Model:  Random Forest Decision Tree Average Accuracy:  0.6843962008141113
# Model:  Decision Tree Average Accuracy:  0.6390321121664405
# Model:  Logistic Regression Average Accuracy:  0.6028493894165535

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=2) 
X_pca = pca.fit_transform(X_scaled)

T = T.astype('int')
X_train, X_test, t_train, t_test = train_test_split(X_pca, T, test_size=0.20, random_state=0)

smote = SMOTE(sampling_strategy='auto', random_state=32)

models = [["K-Nearest Neighbor",knn],["Naive Bayesian", bayes],["Support Vector Machine",svm_classifier],["Gradient Boosting",gb_classifier],["Random Forest Decision Tree",rf_classifier],["Decision Tree",tree_regressor],["Logistic Regression",lr]]

#loop through each model in models array
for model_name, model_instance in models:
    print("{:=^50s}".format(model_name))
    
    #fit the model on the training data
    model_instance.fit(X_train, t_train)
    
    #make predictions on the test data
    y_test = model_instance.predict(X_test)
    
    #used to evalue scores of binary classifiers
    mcc_score = matthews_corrcoef(t_test, y_test)
    print("MCC:",mcc_score)
    
    #print classification report
    cm_report = classification_report(t_test, y_test)
    print(cm_report)
    
    #generate confusion matrix
    cm = confusion_matrix(t_test, y_test)
    
    #display confusion matrix
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(t_test))
    disp.plot(cmap=plt.cm.magma)
    plt.title('Confusion Matrix for ' + model_name) 
    plt.show()
# Out:
# ================K-Nearest Neighbor================
# MCC: 0.2222984693413718
#               precision    recall  f1-score   support
#
#            0       0.44      0.35      0.39        31
#            1       0.80      0.85      0.82        94
#
#     accuracy                           0.73       125
#    macro avg       0.62      0.60      0.61       125
# weighted avg       0.71      0.73      0.72       125
# ==================Naive Bayesian==================
# MCC: 0.21768864116806147
#               precision    recall  f1-score   support
#
#            0       0.67      0.13      0.22        31
#            1       0.77      0.98      0.86        94
#
#     accuracy                           0.77       125
#    macro avg       0.72      0.55      0.54       125
# weighted avg       0.75      0.77      0.70       125
# ==============Support Vector Machine==============
# MCC: 0.0
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        31
#            1       0.75      1.00      0.86        94
#
#     accuracy                           0.75       125
#    macro avg       0.38      0.50      0.43       125
# weighted avg       0.57      0.75      0.65       125
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ================Gradient Boosting=================
# MCC: 0.22914824605976808
#               precision    recall  f1-score   support
#
#            0       0.54      0.23      0.32        31
#            1       0.79      0.94      0.85        94
#
#     accuracy                           0.76       125
#    macro avg       0.66      0.58      0.59       125
# weighted avg       0.72      0.76      0.72       125
# ===========Random Forest Decision Tree============
# MCC: 0.14207275223061083
#               precision    recall  f1-score   support
#
#            0       0.35      0.35      0.35        31
#            1       0.79      0.79      0.79        94
#
#     accuracy                           0.68       125
#    macro avg       0.57      0.57      0.57       125
# weighted avg       0.68      0.68      0.68       125
# ==================Decision Tree===================
# MCC: -0.015672307381219375
#               precision    recall  f1-score   support
#
#            0       0.24      0.35      0.29        31
#            1       0.75      0.63      0.68        94
#
#     accuracy                           0.56       125
#    macro avg       0.49      0.49      0.48       125
# weighted avg       0.62      0.56      0.58       125
# ===============Logistic Regression================
# MCC: 0.1663804451491389
#               precision    recall  f1-score   support
#
#            0       0.60      0.10      0.17        31
#            1       0.77      0.98      0.86        94
#
#     accuracy                           0.76       125
#    macro avg       0.68      0.54      0.51       125
# weighted avg       0.73      0.76      0.69       125

# %%
T = merged_player_data_with_pos['Games']
X = merged_player_data_with_pos.loc[:, (merged_player_data_with_pos.columns != "Games") & (merged_player_data_with_pos.columns != "PlayedGame") & (merged_player_data_with_pos.columns != "Player") & (merged_player_data_with_pos.columns != "Pos_x") & (merged_player_data_with_pos.columns != "Pos_y")]
X
# Out:
#      40yd  Vertical  Bench  BroadJump  3Cone  Shuttle  Pos    Ht   Wt
# 0    4.99      26.5   31.0      108.0   7.31     4.74   14   6.3  314
# 1    5.20      25.0   25.0       98.0   7.60     4.83   14   6.3  310
# 2    5.43      24.0   27.0       92.0   7.90     4.96   14   6.3  302
# 3    5.33      25.5   32.0       96.0   7.83     4.74   14   6.4  310
# 4    5.58      28.5   21.0       97.0   7.81     4.76   14   6.4  312
# ..    ...       ...    ...        ...    ...      ...  ...   ...  ...
# 616  4.38      38.5   17.0      132.0   6.87     4.14    1   6.0  194
# 617  4.51      35.0   10.0      120.0   6.92     4.02    1   5.9  177
# 618  4.60      32.5   17.0      117.0   7.11     4.36   11   6.0  204
# 619  4.47      32.0   16.0      119.0   6.90     4.32    1  5.11  192
# 620  4.54      33.5   19.0      122.0   6.72     4.13   11  5.11  197
#
# [621 rows x 9 columns]

# %%
from sklearn.model_selection import cross_validate

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=2) 
X_pca = pca.fit_transform(X_scaled)

T = T.astype('int')
X_train, X_test, t_train, t_test = train_test_split(X_pca, T, test_size=0.20, random_state=0)

models = [["K-Nearest Neighbor",knn],["Naive Bayesian", bayes],["Support Vector Machine",svm_classifier],["Gradient Boosting",gb_classifier],["Random Forest Decision Tree",rf_classifier],["Decision Tree",tree_regressor],["Logistic Regression",lr],["Linear Regression",linearreg]]

#loop through each model in models array
for model in models:
    #calculate accuracy score using 10-fold cross-validation
    mod = model[1].fit(X_train,t_train)
    rootMeanSquaredError = cross_validate(mod, X_train, t_train, cv=10, scoring=['neg_root_mean_squared_error'],return_train_score=True)
    convertedRMSE = np.abs(np.mean(rootMeanSquaredError['test_neg_root_mean_squared_error']))
    
    print("Model: ", model[0], "Average Accuracy: ", convertedRMSE)
# Out:
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 6 members, which is less than n_splits=10.
#   warnings.warn(
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 6 members, which is less than n_splits=10.
#   warnings.warn(
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 6 members, which is less than n_splits=10.
#   warnings.warn(
# Model:  K-Nearest Neighbor Average Accuracy:  9.36546544062349
# Model:  Naive Bayesian Average Accuracy:  8.86603680546297
# Model:  Support Vector Machine Average Accuracy:  9.1750136053664
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 6 members, which is less than n_splits=10.
#   warnings.warn(
# Model:  Gradient Boosting Average Accuracy:  9.529126893113574
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 6 members, which is less than n_splits=10.
#   warnings.warn(
# Model:  Random Forest Decision Tree Average Accuracy:  9.026712856668548
# Model:  Decision Tree Average Accuracy:  8.795548871974077
# Model:  Logistic Regression Average Accuracy:  8.874521311727943
# Model:  Linear Regression Average Accuracy:  6.395945715744479
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 6 members, which is less than n_splits=10.
#   warnings.warn(
# C:\Users\davis\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 6 members, which is less than n_splits=10.
#   warnings.warn(
